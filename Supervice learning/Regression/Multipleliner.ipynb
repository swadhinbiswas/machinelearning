# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


dataframe = pd.read_csv('EconomiesofBangladesh(1960-2022) .csv')

dataframe
# Out:
#     Year  UnemploymentRate  unemployment changes  InflationRate  \
# 0   2022              4.27                 -0.98           7.70
# 1   2021              5.25                 -0.07           5.55
# 2   2020              5.32                  0.94           5.69
# 3   2019              4.38                  0.00           5.59
# 4   2018              4.37                  0.00           5.54
# ..   ...               ...                   ...            ...
# 58  1964              0.00                  0.00           0.00
# 59  1963              0.00                  0.00           0.00
# 60  1962              0.00                  0.00           0.00
# 61  1961              0.00                  0.00           0.00
# 62  1960              0.00                  0.00           0.00
#
#     InflactionrateChange     GDP  PerCapita  GrowthRate
# 0                   2.15  460.20       2688        7.10
# 1                  -0.15  416.26       2458        6.94
# ...

# %% [markdown]
# # Droping unnecessary colmn

# %%
dataframe.drop(columns=["Year","unemployment changes","InflactionrateChange","GDP"], inplace=True)
dataframe
# Out:
#     UnemploymentRate  InflationRate  PerCapita  GrowthRate
# 0               4.27           7.70       2688        7.10
# 1               5.25           5.55       2458        6.94
# 2               5.32           5.69       2233        3.45
# 3               4.38           5.59       2122        7.88
# 4               4.37           5.54       1963        7.32
# ..               ...            ...        ...         ...
# 58              0.00           0.00         95       10.95
# 59              0.00           0.00         97       -0.46
# 60              0.00           0.00         95        5.45
# 61              0.00           0.00         93        6.06
# 62              0.00           0.00         85        0.00
#
# [63 rows x 4 columns]

# %%
dataframe.isnull().sum()
# Out:
# UnemploymentRate    0
# InflationRate       0
# PerCapita           0
# GrowthRate          0
# dtype: int64

# %%
##visualizing the data

import seaborn as sns

sns.pairplot(dataframe)

# %%
dataframe.corr()
# Out:
#                   UnemploymentRate  InflationRate  PerCapita  GrowthRate
# UnemploymentRate          1.000000       0.724633   0.727461    0.381375
# InflationRate             0.724633       1.000000   0.485031    0.328053
# PerCapita                 0.727461       0.485031   1.000000    0.322510
# GrowthRate                0.381375       0.328053   0.322510    1.000000

# %%
plt.scatter(dataframe['InflationRate'],dataframe['UnemploymentRate'],color='red')
plt.title('Inflation Rate vs Unemployment Rate')
plt.xlabel('Inflation Rate')
plt.ylabel('Unemployment Rate')
# Out:
# Text(0, 0.5, 'Unemployment Rate')

# %%
plt.scatter(dataframe['GrowthRate'],dataframe['UnemploymentRate'],color='blue')
plt.title('Growth Rate vs Unemployment Rate')
plt.xlabel('Growth Rate')
plt.ylabel('Unemployment Rate')
# Out:
# Text(0, 0.5, 'Unemployment Rate')

# %%
plt.scatter(dataframe['GrowthRate'],dataframe['InflationRate'],color='green')
plt.title('Growth Rate vs Inflation Rate')
plt.xlabel('Growth Rate')
plt.ylabel('Inflation Rate')
# Out:
# Text(0, 0.5, 'Inflation Rate')

# %%
plt.scatter(dataframe['GrowthRate'],dataframe['PerCapita'],color='orange')
plt.title('Growth Rate vs Per Capita')
plt.xlabel('Growth Rate')
plt.ylabel('Per Capita')

# %%
plt.scatter(dataframe['GrowthRate'],dataframe['InflationRate'],color='green')
plt.scatter(dataframe['GrowthRate'],dataframe['PerCapita'],color='orange')
plt.scatter(dataframe['GrowthRate'],dataframe['UnemploymentRate'],color='blue')
plt.scatter(dataframe['InflationRate'],dataframe['UnemploymentRate'],color='red')
plt.title('Growth Rate vs Inflation Rate vs Unemployment Rate vs Per Capita')
plt.xlabel('Growth Rate')
plt.ylabel('Inflation Rate vs Unemployment Rate vs Per Capita')
# Out:
# Text(0, 0.5, 'Inflation Rate vs Unemployment Rate vs Per Capita')

# %%
##Independent and dependent variables
y= dataframe['PerCapita']
X = dataframe.drop(columns=['PerCapita'])

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
sns.regplot(x=dataframe['PerCapita'], y=dataframe['InflationRate'])
# Out:
# <Axes: xlabel='PerCapita', ylabel='InflationRate'>

# %%
sns.regplot(x=dataframe['PerCapita'], y=dataframe['UnemploymentRate'])
# Out:
# <Axes: xlabel='PerCapita', ylabel='UnemploymentRate'>

# %%
sns.regplot(x=dataframe['PerCapita'], y=dataframe['GrowthRate'])
# Out:
# <Axes: xlabel='PerCapita', ylabel='GrowthRate'>

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 1.02622295,  0.72613992,  0.54239649],
#        [ 0.20488179,  1.89724076,  0.1717986 ],
#        [-1.02964941,  0.67734406, -0.43174655],
#        [-1.02964941,  1.77381591, -0.18556366],
#        [-1.02964941, -1.05921478, -0.47674772],
#        [ 0.17464837,  0.46493851, -0.15379813],
#        [ 1.17739004,  0.71752889,  0.55033787],
#        [ 1.25297358,  1.49539243,  0.40739297],
#        [ 0.61807182, -0.42486849,  0.21679977],
#        [-1.02964941, -1.05921478, -0.96646637],
#        [-1.02964941, -1.05921478,  1.32859345],
#        [-1.02964941, -1.05921478, -0.61969262],
#        [-1.02964941, -1.05921478,  0.73034257],
#        [-1.02964941, -1.05921478, -0.75734327],
#        [ 1.13203991,  1.11937721,  0.20356413],
#        [-1.02964941, -1.05921478, -1.30529873],
#        [ 0.07890922,  0.76632476, -0.25968324],
#        [ 1.01614515,  1.55566968,  0.68534139],
#        [ 0.10914264, -0.01727948,  0.25650669],
#        [ 1.17235113,  0.57688197,  0.56092638],
# ...

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Cross Validation 

from sklearn.model_selection import cross_val_score
score = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=3)

# %%
score
# Out:
# array([ -94773.79419861, -199174.28520137, -360766.60112004])

# %%
np.mean(score)
# Out:
# -218238.2268400065
